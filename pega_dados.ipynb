# %%
import pandas as pd

df = pd.read_csv('tratamento_1.csv', sep=';')
df
# Out:
#                                Nome  \
# 0             AARON RODRIGUES GOMES
# 1      ABDENAGO ALVES PEREIRA FILHO
# 2      ABDENAGO ALVES PEREIRA FILHO
# 3         ABDENEGO DE PAULA CAMILLO
# 4             ABDIAS COSTA DA SILVA
# ...                             ...
# 50095       ZULEIDE VIEIRA DA SILVA
# 50096        ZULENE AMORIM DA SILVA
# 50097         ZULENE DA SILVA COSTA
# 50098       ZULENE MARQUES DE SOUZA
# 50099         ZULENI LIMA GUIMARAES
#
#                                             Situação  \
# 0                                       EM EXERCÍCIO
# 1                                         APOSENTADO
# 2                                         APOSENTADO
# 3                                       EM EXERCÍCIO
# 4                                       EM EXERCÍCIO
# ...                                              ...
# 50095                                     APOSENTADO
# 50096  AFASTADO/LICENCIADO - TRATAMENTO DE SAUDE - A
# ...

# %%
df['Cargo'] = df['Cargo'].str.strip()
df = df['Cargo']
df
# Out:
# 0                                       MEDICO
# 1                          APOSENTADOS - MEDIA
# 2                 PROFESSOR P2 30H - CLASSE II
# 3                                         CABO
# 4        PROFESSOR N SUPERIOR-P2 CONT TEMP-25H
#                          ...
# 50095              PROFESSOR P2 30H - CLASSE I
# 50096                    TECNICO EM ENFERMAGEM
# 50097                    TECNICO EM ENFERMAGEM
# 50098      APOIO ADMIN. NIVEL I 25H - CLASSE I
# 50099    APOIO ADMIN. NIVEL I 25H - CLASSE III
# Name: Cargo, Length: 50100, dtype: object

# %%
df.to_csv('saida.csv', index=False)
