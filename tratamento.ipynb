# %% [markdown]
# ### Importação e Visualização

# %%
#Import das bibliotecas

import pandas as pd
import numpy as np
import re

# %%
#Ler o arquivo
#update df set Situação = trim(Situação)

df = pd.read_csv("Bases/acre_boladao_JUN_2023.csv", sep=',')
df['id'] = range(len(df))
df['Situação'] = df['Situação'].str.strip()
df
# Out:
#                                Nome      Situação  \
# 0             AARON RODRIGUES GOMES  EM EXERCÍCIO
# 1      ABDENAGO ALVES PEREIRA FILHO    APOSENTADO
# 2      ABDENAGO ALVES PEREIRA FILHO    APOSENTADO
# 3         ABDENEGO DE PAULA CAMILLO  EM EXERCÍCIO
# 4             ABDIAS COSTA DA SILVA  EM EXERCÍCIO
# ...                             ...           ...
# 53685          ZULENI LOURENCO MAIA    APOSENTADO
# 53686          ZULENI LOURENCO MAIA  EM EXERCÍCIO
# 53687        ZULIMA DE LIMA E SILVA   PENSIONISTA
# 53688         ZULINA DA SILVA COSTA    APOSENTADO
# 53689     ZULMIRA PATRICIA DA SILVA    APOSENTADO
#
#                                        Cargo      Bruto  Desconto    Líquido  \
# 0                                     MEDICO  27.798,18  7.147,84  20.650,34
# 1                        APOSENTADOS - MEDIA   4.975,59    364,80   4.610,79
# 2               PROFESSOR P2 30H - CLASSE II   5.329,95  2.599,55   2.730,40
# 3                        3º SARGENTO NIVEL A  12.366,86  4.268,13   8.098,73
# 4      PROFESSOR N SUPERIOR-P2 CONT TEMP-25H   7.041,88  2.295,00   4.746,88
# ...                                      ...        ...       ...        ...
# 53685            PROFESSOR P2 30H - CLASSE I   6.984,18  2.189,98   4.794,20
# 53686  PROFESSOR N SUPERIOR-P2 CONT TEMP-25H   3.890,67    390,53   3.500,14
# 53687                            PENSIONISTA     888,60      0,00     888,60
# 53688           PROFESSOR P2 30H - CLASSE II   7.507,99  2.703,14   4.804,85
# 53689  AUXILIAR OPERACIONAL DE SERV DIVERSOS   1.699,15    452,52   1.246,63
#
#           id
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
# ...      ...
# 53685  53685
# 53686  53686
# 53687  53687
# 53688  53688
# 53689  53689
#
# [53690 rows x 7 columns]

# %% [markdown]
# ### Tratamento de colunas com dados repetidos

# %%
#Copiar para um novo dataframe os que estão a coluna SITUAÇÃO errada

df_tratar = df[df['Líquido'].isnull()]
df_tratar
# Out:
#                                   Nome  \
# 5            ABDIAS DAMASCENO DA SILVA
# 27                  ABILIO BENTO FILHO
# 28                 ABILIO CLOVIS SILVA
# 29             ABILIO DOS SANTOS VERAS
# 36                ABRAAO DA SILVA LIMA
# ...                                ...
# 53587  ZILDA JUCILANE BORDINHAO SOARES
# 53604           ZILMA GOMES CAVALCANTE
# 53608          ZILMA MARIA MATOS VIANA
# 53650           ZULEIDE CAMELI MESSIAS
# 53660        ZULEIDE DE OLIVEIRA COUTO
#
#                                                Situação      Cargo     Bruto  \
# 5                EM EXERCÍCIO CARGO EM COMISSAO - CAS-2   2.746,28    189,56
# 27                 EM EXERCÍCIO CAS2 - FEM - LEI Nº 427   2.746,28    189,56
# 28                        EM EXERCÍCIO CEC-4 - CAGEACRE   4.651,61    603,48
# 29        EM EXERCÍCIO CEC-5 - L1688/05 ACREPREVIDENCIA   6.086,16  1.144,14
# 36                                 EM EXERCÍCIO CAPITAO  15.481,52  7.562,31
# ...                                                 ...        ...       ...
# 53587            EM EXERCÍCIO CARGO EM COMISSAO - CAS-6   7.376,70  1.608,02
# 53604          EM EXERCÍCIO SERVICOS GERAIS - CODISACRE   2.496,53    554,83
# 53608                          EM EXERCÍCIO DATILOGRAFO   4.168,31    307,54
# 53650  EM EXERCÍCIO VOGAL DE CRUZEIRO DO SUL 1 - JUCEAC   1.866,35    148,17
# 53660           APOSENTADO GESTOR DE POLITICAS PUBLICAS  13.690,22  6.969,89
#
#        Desconto Líquido     id
# 5      2.556,72     NaN      5
# 27     2.556,72     NaN     27
# 28     4.048,13     NaN     28
# 29     4.942,02     NaN     29
# 36     7.919,21     NaN     36
# ...         ...     ...    ...
# 53587  5.768,68     NaN  53587
# 53604  1.941,70     NaN  53604
# 53608  3.860,77     NaN  53608
# 53650  1.718,18     NaN  53650
# 53660  6.720,33     NaN  53660
#
# [8979 rows x 7 columns]

# %%
#Realocar as colunas paras as posições certas

df_tratar['Líquido'], df_tratar['Bruto'], df_tratar['Desconto'], df_tratar['Cargo'] = df_tratar['Desconto'], df_tratar['Cargo'], df_tratar['Bruto'], df_tratar['Situação']
df_tratar
# Out:
# C:\Users\abner\AppData\Local\Temp\ipykernel_15792\1270212053.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tratar['Líquido'], df_tratar['Bruto'], df_tratar['Desconto'], df_tratar['Cargo'] = df_tratar['Desconto'], df_tratar['Cargo'], df_tratar['Bruto'], df_tratar['Situação']
#                                   Nome  \
# 5            ABDIAS DAMASCENO DA SILVA
# 27                  ABILIO BENTO FILHO
# 28                 ABILIO CLOVIS SILVA
# 29             ABILIO DOS SANTOS VERAS
# 36                ABRAAO DA SILVA LIMA
# ...                                ...
# 53587  ZILDA JUCILANE BORDINHAO SOARES
# 53604           ZILMA GOMES CAVALCANTE
# 53608          ZILMA MARIA MATOS VIANA
# 53650           ZULEIDE CAMELI MESSIAS
# 53660        ZULEIDE DE OLIVEIRA COUTO
#
#                                                Situação  \
# 5                EM EXERCÍCIO CARGO EM COMISSAO - CAS-2
# 27                 EM EXERCÍCIO CAS2 - FEM - LEI Nº 427
# 28                        EM EXERCÍCIO CEC-4 - CAGEACRE
# 29        EM EXERCÍCIO CEC-5 - L1688/05 ACREPREVIDENCIA
# 36                                 EM EXERCÍCIO CAPITAO
# ...                                                 ...
# 53587            EM EXERCÍCIO CARGO EM COMISSAO - CAS-6
# 53604          EM EXERCÍCIO SERVICOS GERAIS - CODISACRE
# 53608                          EM EXERCÍCIO DATILOGRAFO
# 53650  EM EXERCÍCIO VOGAL DE CRUZEIRO DO SUL 1 - JUCEAC
# 53660           APOSENTADO GESTOR DE POLITICAS PUBLICAS
#
#                                                   Cargo      Bruto  Desconto  \
# 5                EM EXERCÍCIO CARGO EM COMISSAO - CAS-2   2.746,28    189,56
# 27                 EM EXERCÍCIO CAS2 - FEM - LEI Nº 427   2.746,28    189,56
# 28                        EM EXERCÍCIO CEC-4 - CAGEACRE   4.651,61    603,48
# 29        EM EXERCÍCIO CEC-5 - L1688/05 ACREPREVIDENCIA   6.086,16  1.144,14
# 36                                 EM EXERCÍCIO CAPITAO  15.481,52  7.562,31
# ...                                                 ...        ...       ...
# 53587            EM EXERCÍCIO CARGO EM COMISSAO - CAS-6   7.376,70  1.608,02
# 53604          EM EXERCÍCIO SERVICOS GERAIS - CODISACRE   2.496,53    554,83
# 53608                          EM EXERCÍCIO DATILOGRAFO   4.168,31    307,54
# 53650  EM EXERCÍCIO VOGAL DE CRUZEIRO DO SUL 1 - JUCEAC   1.866,35    148,17
# 53660           APOSENTADO GESTOR DE POLITICAS PUBLICAS  13.690,22  6.969,89
#
#         Líquido     id
# 5      2.556,72      5
# 27     2.556,72     27
# 28     4.048,13     28
# 29     4.942,02     29
# 36     7.919,21     36
# ...         ...    ...
# 53587  5.768,68  53587
# 53604  1.941,70  53604
# 53608  3.860,77  53608
# 53650  1.718,18  53650
# 53660  6.720,33  53660
#
# [8979 rows x 7 columns]

# %%
#Tratar a Coluna Cargo

palavras_a_remover_0 = ['APOSENTADO', 'EM EXERCÍCIO', 'EM FÉRIAS', 'PENSIONISTA', 'AFASTADO/LICENCIADO']
for palavra in palavras_a_remover_0:
    df_tratar['Cargo'] = df_tratar['Cargo'].str.replace(f'^{palavra}', '', regex=True)

df_tratar
# Out:
# C:\Users\abner\AppData\Local\Temp\ipykernel_15792\3213047085.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tratar['Cargo'] = df_tratar['Cargo'].str.replace(f'^{palavra}', '', regex=True)
#                                   Nome  \
# 5            ABDIAS DAMASCENO DA SILVA
# 27                  ABILIO BENTO FILHO
# 28                 ABILIO CLOVIS SILVA
# 29             ABILIO DOS SANTOS VERAS
# 36                ABRAAO DA SILVA LIMA
# ...                                ...
# 53587  ZILDA JUCILANE BORDINHAO SOARES
# 53604           ZILMA GOMES CAVALCANTE
# 53608          ZILMA MARIA MATOS VIANA
# 53650           ZULEIDE CAMELI MESSIAS
# 53660        ZULEIDE DE OLIVEIRA COUTO
#
#                                                Situação  \
# 5                EM EXERCÍCIO CARGO EM COMISSAO - CAS-2
# 27                 EM EXERCÍCIO CAS2 - FEM - LEI Nº 427
# 28                        EM EXERCÍCIO CEC-4 - CAGEACRE
# 29        EM EXERCÍCIO CEC-5 - L1688/05 ACREPREVIDENCIA
# 36                                 EM EXERCÍCIO CAPITAO
# ...                                                 ...
# 53587            EM EXERCÍCIO CARGO EM COMISSAO - CAS-6
# 53604          EM EXERCÍCIO SERVICOS GERAIS - CODISACRE
# 53608                          EM EXERCÍCIO DATILOGRAFO
# 53650  EM EXERCÍCIO VOGAL DE CRUZEIRO DO SUL 1 - JUCEAC
# 53660           APOSENTADO GESTOR DE POLITICAS PUBLICAS
#
#                                       Cargo      Bruto  Desconto   Líquido  \
# 5                 CARGO EM COMISSAO - CAS-2   2.746,28    189,56  2.556,72
# 27                  CAS2 - FEM - LEI Nº 427   2.746,28    189,56  2.556,72
# 28                         CEC-4 - CAGEACRE   4.651,61    603,48  4.048,13
# 29         CEC-5 - L1688/05 ACREPREVIDENCIA   6.086,16  1.144,14  4.942,02
# 36                                  CAPITAO  15.481,52  7.562,31  7.919,21
# ...                                     ...        ...       ...       ...
# 53587             CARGO EM COMISSAO - CAS-6   7.376,70  1.608,02  5.768,68
# 53604           SERVICOS GERAIS - CODISACRE   2.496,53    554,83  1.941,70
# 53608                           DATILOGRAFO   4.168,31    307,54  3.860,77
# 53650   VOGAL DE CRUZEIRO DO SUL 1 - JUCEAC   1.866,35    148,17  1.718,18
# 53660          GESTOR DE POLITICAS PUBLICAS  13.690,22  6.969,89  6.720,33
#
#           id
# 5          5
# 27        27
# 28        28
# 29        29
# 36        36
# ...      ...
# 53587  53587
# 53604  53604
# 53608  53608
# 53650  53650
# 53660  53660
#
# [8979 rows x 7 columns]

# %%
#Tratar a coluna Situação

palavras_a_remover_1 = df_tratar['Cargo']

# Aplicar a remoção das palavras à coluna 'Situação'
for palavra in palavras_a_remover_1:
    df_tratar['Situação'] = df_tratar['Situação'].str.replace(fr'\b{palavra}\b', '', regex=True, case=False).str.strip()
df_tratar
# Out:
# C:\Users\abner\AppData\Local\Temp\ipykernel_15792\3685544799.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tratar['Situação'] = df_tratar['Situação'].str.replace(fr'\b{palavra}\b', '', regex=True, case=False).str.strip()
#                                   Nome      Situação  \
# 5            ABDIAS DAMASCENO DA SILVA  EM EXERCÍCIO
# 27                  ABILIO BENTO FILHO  EM EXERCÍCIO
# 28                 ABILIO CLOVIS SILVA  EM EXERCÍCIO
# 29             ABILIO DOS SANTOS VERAS  EM EXERCÍCIO
# 36                ABRAAO DA SILVA LIMA  EM EXERCÍCIO
# ...                                ...           ...
# 53587  ZILDA JUCILANE BORDINHAO SOARES  EM EXERCÍCIO
# 53604           ZILMA GOMES CAVALCANTE  EM EXERCÍCIO
# 53608          ZILMA MARIA MATOS VIANA  EM EXERCÍCIO
# 53650           ZULEIDE CAMELI MESSIAS  EM EXERCÍCIO
# 53660        ZULEIDE DE OLIVEIRA COUTO    APOSENTADO
#
#                                       Cargo      Bruto  Desconto   Líquido  \
# 5                 CARGO EM COMISSAO - CAS-2   2.746,28    189,56  2.556,72
# 27                  CAS2 - FEM - LEI Nº 427   2.746,28    189,56  2.556,72
# 28                         CEC-4 - CAGEACRE   4.651,61    603,48  4.048,13
# 29         CEC-5 - L1688/05 ACREPREVIDENCIA   6.086,16  1.144,14  4.942,02
# 36                                  CAPITAO  15.481,52  7.562,31  7.919,21
# ...                                     ...        ...       ...       ...
# 53587             CARGO EM COMISSAO - CAS-6   7.376,70  1.608,02  5.768,68
# 53604           SERVICOS GERAIS - CODISACRE   2.496,53    554,83  1.941,70
# 53608                           DATILOGRAFO   4.168,31    307,54  3.860,77
# 53650   VOGAL DE CRUZEIRO DO SUL 1 - JUCEAC   1.866,35    148,17  1.718,18
# 53660          GESTOR DE POLITICAS PUBLICAS  13.690,22  6.969,89  6.720,33
#
#           id
# 5          5
# 27        27
# 28        28
# 29        29
# 36        36
# ...      ...
# 53587  53587
# 53604  53604
# 53608  53608
# 53650  53650
# 53660  53660
#
# [8979 rows x 7 columns]

# %%
df_tratar_2 = df_tratar[df_tratar['Líquido'].isnull()]
df_tratar_2
# Out:
# Empty DataFrame
# Columns: [Nome, Situação, Cargo, Bruto, Desconto, Líquido, id]
# Index: []

# %% [markdown]
# ### Final - Salvando Arquivo

# %%
#excluir a coluna ID e salvar o arquivo Finalizado

df.drop(columns=['id'], inplace=True)

df.update(df_tratar)

df.to_csv('Bases/acre_boladao_MAI_2023_tratado.csv', index=False, sep=';')

# %% [markdown]
# ### Outros Testes

# %%
df_tratar_2 = df_tratar[df_tratar['Líquido'].isnull()]
df_tratar_2['Líquido'], df_tratar_2['Bruto'], df_tratar_2['Desconto'], df_tratar_2['Cargo'] = df_tratar_2['Desconto'], df_tratar_2['Cargo'], df_tratar_2['Bruto'], df_tratar_2['Situação']
df_tratar_2
# Out:
# C:\Users\abner\AppData\Local\Temp\ipykernel_15792\1562671528.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tratar_2['Líquido'], df_tratar_2['Bruto'], df_tratar_2['Desconto'], df_tratar_2['Cargo'] = df_tratar_2['Desconto'], df_tratar_2['Cargo'], df_tratar_2['Bruto'], df_tratar_2['Situação']
#                                                     Nome Situação Cargo  \
# 2959   ANDERSON DE ARAUJO SILVA EXONERADO/RESCISO OPE...
# 3249   ANDREY CEZAR WINDSCHEID CRUZEIRO DE HOLL CEDID...
# 4905     ANTONIO PINTO DE LIMA JUNIOR CEDIDO DATILOGRAFO
# 8432   DANGELA LIMA DE MENEZES OLIVEIRA EXONERADO/RES...
# 8785   DAVID LAERTE VIEIRA CEDIDO PROCURADOR DO ESTAD...
# 12847  EVANDRO LUZIA TEIXEIRA CEDIDO GESTOR DE POLITI...
# 15993  FRANCISCO JURANDIR DE LIMA VICTOR EXONERADO/RE...
# 16233  FRANCISCO RAILDO CARDOSO LEITAO CEDIDO ESPECIA...
# 16249  FRANCISCO RAULINO SARAIVA DE FARIAS CEDIDO ECO...
# 16560  GABRIEL ISAAC DO VALE ISRAEL CEDIDO ENGENHEIRO...
# 16594  GABRIELA LIMA GEBER EXONERADO/RESCISO ORIENTAD...
# 18236  HERIKA DE ALENCAR TEIXEIRA BEZERRA CEDIDO SECR...
# 18453  IARA GUEDES BEZERRA CEDIDO GESTOR DE POLITICAS...
# 18973  IRISNAILA LIMA BELEM CEDIDO GESTOR DE POLITICA...
# 20159  JANAINA GUEDES BEZERRA DOURADO CEDIDO GESTOR D...
# 22522  JOSE CLAUDIO SILVA DE SOUSA CEDIDO ARTIFICE DE...
# 25101  KEULY TAVARES QUEIROZ COSTA CEDIDO GESTOR DE P...
# 26504  LUCIA NASSERALA VERA DA COSTA CEDIDO GESTOR DE...
# 26915  LUIS ANDRE PINTO DE LIMA EXONERADO/RESCISO CAR...
# 28747  MARCUS ALEXANDRE MEDICI AGUIAR VIANA DA CEDIDO...
# 36782  MARILENE DA SILVA LIMA CEDIDO GESTOR DE POLITI...
# 37524  MARLY DA COSTA ALENCAR SILVA CEDIDO GESTOR DE ...
# 38284  MIRELLA UCHOA PEREIRA DE SOUZA EXONERADO/RESCI...
# 38811  NARAH GLEID MAZZARO NASCIMENTO EXONERADO/RESCI...
# 40655  PAULO SILVA CESARIO ROSA EXONERADO/RESCISO CAR...
# 40836  PEDRO NOGUEIRA BRILHANTE JUNIOR CEDIDO ESPECIA...
# 41144  RAFAEL MARCOS COSTA PIMENTEL CEDIDO DELEGADO C...
# 42949  REJANEA MOURA DE BRITO SOUZA CEDIDO GESTOR DE ...
# 43601             RODOLFO QUIROGA ELIAS CEDIDO ARQUITETO
# 44956  SABRINA SILVA DE SOUZA JUCA CEDIDO GESTOR DE P...
# 45360  SANIA FRANCISCA RODRIGUES DA SILVA EXONERADO/R...
# 46092  SHELLEY TORRES DE OLIVEIRA CEDIDO ESPECIALISTA...
# 47664  THAIS ALICE BASTOS DA COSTA MAIA CEDIDO AGENTE...
# 47811  THIAGO ANDRE REGO CHAVES CEDIDO ESPECIALISTA E...
# 48453  VALMIRA BRAGA E SILVA EXONERADO/RESCISO ASSIST...
# 48537  VANDER MAGALHAES NICACIO CEDIDO ESPECIALISTA E...
# 49224  WAGNER SOARES DE SOUZA CEDIDO GESTOR DE POLITI...
#
#            Bruto   Desconto    Líquido     id
# 2959       74,54       4,34      70,20   2959
# 3249   34.321,03  12.206,29  22.114,74   3249
# 4905    2.156,72     738,91   1.417,81   4905
# 8432    1.334,20      79,06   1.255,14   8432
# 8785   39.633,08  15.845,59  23.787,49   8785
# 12847   9.459,73   4.750,76   4.708,97  12847
# 15993  11.106,13   2.709,17   8.396,96  15993
# 16233  11.167,19   6.048,84   5.118,35  16233
# 16249   5.169,08   2.004,30   3.164,78  16249
# 16560  10.068,32   3.806,61   6.261,71  16560
# 16594     586,80     162,37     424,43  16594
# 18236   5.230,46     968,82   4.261,64  18236
# 18453  12.087,19   3.664,16   8.423,03  18453
# 18973   5.953,75   1.889,55   4.064,20  18973
# 20159   9.294,16   2.946,11   6.348,05  20159
# 22522   2.901,93   1.049,26   1.852,67  22522
# 25101  11.667,19   6.595,13   5.072,06  25101
# 26504  11.667,19   7.463,85   4.203,34  26504
# 26915   5.618,49     967,53   4.650,96  26915
# 28747  10.485,40   3.003,77   7.481,63  28747
# 36782  12.645,54   4.661,38   7.984,16  36782
# 37524  12.087,19   6.987,82   5.099,37  37524
# 38284   5.614,04     961,38   4.652,66  38284
# 38811   5.744,55   1.088,38   4.656,17  38811
# 40655   5.361,58     951,89   4.409,69  40655
# 40836  13.487,19   5.232,13   8.255,06  40836
# 41144  30.476,03  16.205,65  14.270,38  41144
# 42949  12.087,19   6.604,19   5.483,00  42949
# 43601   9.821,00   3.906,14   5.914,86  43601
# 44956   6.782,78   1.475,48   5.307,30  44956
# 45360   7.514,04   1.936,10   5.577,94  45360
# 46092   9.771,30   3.063,28   6.708,02  46092
# 47664   4.010,68   1.071,93   2.938,75  47664
# 47811   9.771,30   5.266,85   4.504,45  47811
# 48453   5.614,04     961,38   4.652,66  48453
# 48537  11.167,19   6.204,91   4.962,28  48537
# 49224  10.691,30   6.064,93   4.626,37  49224

# %%
df_tratar_2['Situação'] = df_tratar_2['Nome']
df_tratar_2
# Out:
# C:\Users\abner\AppData\Local\Temp\ipykernel_21492\569472362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tratar_2['Situação'] = df_tratar_2['Nome']
#                                                     Nome  \
# 2959          ANDERSON DE ARAUJO SILVA EXONERADO/RESCISO
# 3249     ANDREY CEZAR WINDSCHEID CRUZEIRO DE HOLL CEDIDO
# 4905                 ANTONIO PINTO DE LIMA JUNIOR CEDIDO
# 8432   DANGELA LIMA DE MENEZES OLIVEIRA EXONERADO/RES...
# 8785                          DAVID LAERTE VIEIRA CEDIDO
# 12847                      EVANDRO LUZIA TEIXEIRA CEDIDO
# 15993  FRANCISCO JURANDIR DE LIMA VICTOR EXONERADO/RE...
# 16233             FRANCISCO RAILDO CARDOSO LEITAO CEDIDO
# 16249         FRANCISCO RAULINO SARAIVA DE FARIAS CEDIDO
# 16560                GABRIEL ISAAC DO VALE ISRAEL CEDIDO
# 16594              GABRIELA LIMA GEBER EXONERADO/RESCISO
# 18236          HERIKA DE ALENCAR TEIXEIRA BEZERRA CEDIDO
# 18453                         IARA GUEDES BEZERRA CEDIDO
# 18973                        IRISNAILA LIMA BELEM CEDIDO
# 20159              JANAINA GUEDES BEZERRA DOURADO CEDIDO
# 22522                 JOSE CLAUDIO SILVA DE SOUSA CEDIDO
# 25101                 KEULY TAVARES QUEIROZ COSTA CEDIDO
# 26504               LUCIA NASSERALA VERA DA COSTA CEDIDO
# 26915         LUIS ANDRE PINTO DE LIMA EXONERADO/RESCISO
# 28747     MARCUS ALEXANDRE MEDICI AGUIAR VIANA DA CEDIDO
# 36782                      MARILENE DA SILVA LIMA CEDIDO
# 37524                MARLY DA COSTA ALENCAR SILVA CEDIDO
# 38284   MIRELLA UCHOA PEREIRA DE SOUZA EXONERADO/RESCISO
# 38811   NARAH GLEID MAZZARO NASCIMENTO EXONERADO/RESCISO
# 40655         PAULO SILVA CESARIO ROSA EXONERADO/RESCISO
# 40836  PEDRO NOGUEIRA BRILHANTE JUNIOR CEDIDO ESPECIA...
# 41144                RAFAEL MARCOS COSTA PIMENTEL CEDIDO
# 42949                REJANEA MOURA DE BRITO SOUZA CEDIDO
# 43601                       RODOLFO QUIROGA ELIAS CEDIDO
# 44956                 SABRINA SILVA DE SOUZA JUCA CEDIDO
# 45360  SANIA FRANCISCA RODRIGUES DA SILVA EXONERADO/R...
# 46092  SHELLEY TORRES DE OLIVEIRA CEDIDO ESPECIALISTA...
# 47664            THAIS ALICE BASTOS DA COSTA MAIA CEDIDO
# 47811                    THIAGO ANDRE REGO CHAVES CEDIDO
# 48453            VALMIRA BRAGA E SILVA EXONERADO/RESCISO
# 48537                    VANDER MAGALHAES NICACIO CEDIDO
# 49224                      WAGNER SOARES DE SOUZA CEDIDO
#
#                                                 Situação Cargo      Bruto  \
# 2959          ANDERSON DE ARAUJO SILVA EXONERADO/RESCISO            74,54
# 3249     ANDREY CEZAR WINDSCHEID CRUZEIRO DE HOLL CEDIDO        34.321,03
# 4905                 ANTONIO PINTO DE LIMA JUNIOR CEDIDO         2.156,72
# 8432   DANGELA LIMA DE MENEZES OLIVEIRA EXONERADO/RES...         1.334,20
# 8785                          DAVID LAERTE VIEIRA CEDIDO        39.633,08
# 12847                      EVANDRO LUZIA TEIXEIRA CEDIDO         9.459,73
# 15993  FRANCISCO JURANDIR DE LIMA VICTOR EXONERADO/RE...        11.106,13
# 16233             FRANCISCO RAILDO CARDOSO LEITAO CEDIDO        11.167,19
# 16249         FRANCISCO RAULINO SARAIVA DE FARIAS CEDIDO         5.169,08
# 16560                GABRIEL ISAAC DO VALE ISRAEL CEDIDO        10.068,32
# 16594              GABRIELA LIMA GEBER EXONERADO/RESCISO           586,80
# 18236          HERIKA DE ALENCAR TEIXEIRA BEZERRA CEDIDO         5.230,46
# 18453                         IARA GUEDES BEZERRA CEDIDO        12.087,19
# 18973                        IRISNAILA LIMA BELEM CEDIDO         5.953,75
# 20159              JANAINA GUEDES BEZERRA DOURADO CEDIDO         9.294,16
# 22522                 JOSE CLAUDIO SILVA DE SOUSA CEDIDO         2.901,93
# 25101                 KEULY TAVARES QUEIROZ COSTA CEDIDO        11.667,19
# 26504               LUCIA NASSERALA VERA DA COSTA CEDIDO        11.667,19
# 26915         LUIS ANDRE PINTO DE LIMA EXONERADO/RESCISO         5.618,49
# 28747     MARCUS ALEXANDRE MEDICI AGUIAR VIANA DA CEDIDO        10.485,40
# 36782                      MARILENE DA SILVA LIMA CEDIDO        12.645,54
# 37524                MARLY DA COSTA ALENCAR SILVA CEDIDO        12.087,19
# 38284   MIRELLA UCHOA PEREIRA DE SOUZA EXONERADO/RESCISO         5.614,04
# 38811   NARAH GLEID MAZZARO NASCIMENTO EXONERADO/RESCISO         5.744,55
# 40655         PAULO SILVA CESARIO ROSA EXONERADO/RESCISO         5.361,58
# 40836  PEDRO NOGUEIRA BRILHANTE JUNIOR CEDIDO ESPECIA...        13.487,19
# 41144                RAFAEL MARCOS COSTA PIMENTEL CEDIDO        30.476,03
# 42949                REJANEA MOURA DE BRITO SOUZA CEDIDO        12.087,19
# 43601                       RODOLFO QUIROGA ELIAS CEDIDO         9.821,00
# 44956                 SABRINA SILVA DE SOUZA JUCA CEDIDO         6.782,78
# 45360  SANIA FRANCISCA RODRIGUES DA SILVA EXONERADO/R...         7.514,04
# 46092  SHELLEY TORRES DE OLIVEIRA CEDIDO ESPECIALISTA...         9.771,30
# 47664            THAIS ALICE BASTOS DA COSTA MAIA CEDIDO         4.010,68
# 47811                    THIAGO ANDRE REGO CHAVES CEDIDO         9.771,30
# 48453            VALMIRA BRAGA E SILVA EXONERADO/RESCISO         5.614,04
# 48537                    VANDER MAGALHAES NICACIO CEDIDO        11.167,19
# 49224                      WAGNER SOARES DE SOUZA CEDIDO        10.691,30
#
#         Desconto    Líquido     id
# 2959        4,34      70,20   2959
# 3249   12.206,29  22.114,74   3249
# 4905      738,91   1.417,81   4905
# 8432       79,06   1.255,14   8432
# 8785   15.845,59  23.787,49   8785
# 12847   4.750,76   4.708,97  12847
# 15993   2.709,17   8.396,96  15993
# 16233   6.048,84   5.118,35  16233
# 16249   2.004,30   3.164,78  16249
# 16560   3.806,61   6.261,71  16560
# 16594     162,37     424,43  16594
# 18236     968,82   4.261,64  18236
# 18453   3.664,16   8.423,03  18453
# 18973   1.889,55   4.064,20  18973
# 20159   2.946,11   6.348,05  20159
# 22522   1.049,26   1.852,67  22522
# 25101   6.595,13   5.072,06  25101
# 26504   7.463,85   4.203,34  26504
# 26915     967,53   4.650,96  26915
# 28747   3.003,77   7.481,63  28747
# 36782   4.661,38   7.984,16  36782
# 37524   6.987,82   5.099,37  37524
# 38284     961,38   4.652,66  38284
# 38811   1.088,38   4.656,17  38811
# 40655     951,89   4.409,69  40655
# 40836   5.232,13   8.255,06  40836
# 41144  16.205,65  14.270,38  41144
# 42949   6.604,19   5.483,00  42949
# 43601   3.906,14   5.914,86  43601
# 44956   1.475,48   5.307,30  44956
# 45360   1.936,10   5.577,94  45360
# 46092   3.063,28   6.708,02  46092
# 47664   1.071,93   2.938,75  47664
# 47811   5.266,85   4.504,45  47811
# 48453     961,38   4.652,66  48453
# 48537   6.204,91   4.962,28  48537
# 49224   6.064,93   4.626,37  49224
